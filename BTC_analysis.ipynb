# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv('BTC-USD.csv')
data = pd.DataFrame(file)

# %%
print(data.columns)
print(data.head())
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#          Date         Open         High          Low        Close  \
# 0  2018-04-26  9289.009766  9385.870117  8923.480469  8938.469727
# 1  2018-04-27  8938.469727  9435.900391  8892.519531  9351.469727
# 2  2018-04-28  9349.940430  9552.669922  9189.070313  9407.040039
# 3  2018-04-29  9407.349609  9459.809570  9133.599609  9248.450195
# 4  2018-04-30  9248.250000  9251.660156  8851.099609  9077.280273
#
#      Adj Close     Volume
# 0  8938.469727  758182407
# 1  9351.469727  774111704
# 2  9407.040039  640931911
# 3  9248.450195  574099218
# 4  9077.280273  669555436

# %%
print(data.tail())
# Out:
#           Date         Open         High          Low        Close  \
# 26  2018-05-22  7992.750000  8031.629883  7460.660156  7505.770020
# 27  2018-05-23  7505.770020  7729.479980  7283.770020  7584.740234
# 28  2018-05-24  7584.779785  7652.370117  7347.959961  7475.359863
# 29  2018-05-25  7475.359863  7626.689941  7314.709961  7355.060059
# 30  2018-05-27  7355.060059  7420.069824  7256.669922  7344.759766
#
#       Adj Close     Volume
# 26  7505.770020  934151146
# 27  7584.740234  826278113
# 28  7475.359863  634474356
# 29  7355.060059  368322782
# 30  7344.759766  320265632

# %%
close_series = file['Close']

# %%
close_series.plot()
plt.show()

# %%
data.plot(subplots=True)
plt.show()

# %%
data.plot(kind='box',x='Date')
plt.show()
